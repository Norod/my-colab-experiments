# %% [markdown]
# <a href="https://colab.research.google.com/github/Norod/my-colab-experiments/blob/master/kakaobrain_minDALL_E_sampling_interactive_colab_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !git clone https://github.com/kakaobrain/minDALL-E
# %cd ./minDALL-E
# !pip install -r ./requirements.txt
# Out:
# /content
# Cloning into 'minDALL-E'...
# remote: Enumerating objects: 86, done.
# remote: Counting objects: 100% (86/86), done.
# remote: Compressing objects: 100% (80/80), done.
# remote: Total 86 (delta 9), reused 76 (delta 5), pack-reused 0
# Unpacking objects: 100% (86/86), done.
# /content/minDALL-E
# Collecting git+https://github.com/openai/CLIP.git (from -r ./requirements.txt (line 9))
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-02t2ou8v
#   Running command git clone -q https://github.com/openai/CLIP.git /tmp/pip-req-build-02t2ou8v
# Collecting torch==1.8.0
#   Downloading torch-1.8.0-cp37-cp37m-manylinux1_x86_64.whl (735.5 MB)
#      |████████████████████████████████| 735.5 MB 14 kB/s
# Requirement already satisfied: torchvision>=0.8.2 in /usr/local/lib/python3.7/dist-packages (from -r ./requirements.txt (line 2)) (0.11.1+cu111)
# Collecting tokenizers>=0.10.2
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 80.3 MB/s
# Collecting pyflakes>=2.2.0
#   Downloading pyflakes-2.4.0-py2.py3-none-any.whl (69 kB)
#      |████████████████████████████████| 69 kB 9.1 MB/s
# Requirement already satisfied: tqdm>=4.46.0 in /usr/local/lib/python3.7/dist-packages (from -r ./requirements.txt (line 5)) (4.62.3)
# Collecting pytorch-lightning>=1.5
#   Downloading pytorch_lightning-1.5.6-py3-none-any.whl (525 kB)
#      |████████████████████████████████| 525 kB 61.0 MB/s
# Collecting einops
#   Downloading einops-0.3.2-py3-none-any.whl (25 kB)
# Collecting omegaconf
#   Downloading omegaconf-2.1.1-py3-none-any.whl (74 kB)
#      |████████████████████████████████| 74 kB 4.5 MB/s
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from -r ./requirements.txt (line 10)) (3.2.2)
# Collecting ftfy
#   Downloading ftfy-6.0.3.tar.gz (64 kB)
#      |████████████████████████████████| 64 kB 3.6 MB/s
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from clip==1.0->-r ./requirements.txt (line 9)) (2019.12.20)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.8.0->-r ./requirements.txt (line 1)) (3.10.0.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch==1.8.0->-r ./requirements.txt (line 1)) (1.19.5)
# Collecting torchvision>=0.8.2
#   Downloading torchvision-0.11.2-cp37-cp37m-manylinux1_x86_64.whl (23.3 MB)
#      |████████████████████████████████| 23.3 MB 1.3 MB/s
#   Downloading torchvision-0.11.1-cp37-cp37m-manylinux1_x86_64.whl (23.3 MB)
#      |████████████████████████████████| 23.3 MB 1.1 MB/s
#   Downloading torchvision-0.10.1-cp37-cp37m-manylinux1_x86_64.whl (22.1 MB)
#      |████████████████████████████████| 22.1 MB 100.6 MB/s
# Requirement already satisfied: pillow>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision>=0.8.2->-r ./requirements.txt (line 2)) (7.1.2)
#   Downloading torchvision-0.10.0-cp37-cp37m-manylinux1_x86_64.whl (22.1 MB)
#      |████████████████████████████████| 22.1 MB 1.1 MB/s
#   Downloading torchvision-0.9.1-cp37-cp37m-manylinux1_x86_64.whl (17.4 MB)
#      |████████████████████████████████| 17.4 MB 76.3 MB/s
#   Downloading torchvision-0.9.0-cp37-cp37m-manylinux1_x86_64.whl (17.3 MB)
#      |████████████████████████████████| 17.3 MB 22 kB/s
# Collecting PyYAML>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 81.6 MB/s
# Collecting torchmetrics>=0.4.1
#   Downloading torchmetrics-0.6.2-py3-none-any.whl (332 kB)
#      |████████████████████████████████| 332 kB 94.7 MB/s
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.5->-r ./requirements.txt (line 6)) (2.7.0)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.5->-r ./requirements.txt (line 6)) (21.3)
# Collecting fsspec[http]!=2021.06.0,>=2021.05.0
#   Downloading fsspec-2021.11.1-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 100.7 MB/s
# Collecting pyDeprecate==0.3.1
#   Downloading pyDeprecate-0.3.1-py3-none-any.whl (10 kB)
# Collecting future>=0.17.1
#   Downloading future-0.18.2.tar.gz (829 kB)
#      |████████████████████████████████| 829 kB 70.0 MB/s
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 57.6 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.5->-r ./requirements.txt (line 6)) (2.23.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=17.0->pytorch-lightning>=1.5->-r ./requirements.txt (line 6)) (3.0.6)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.5->-r ./requirements.txt (line 6)) (0.37.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.5->-r ./requirements.txt (line 6)) (0.12.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.5->-r ./requirements.txt (line 6)) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.5->-r ./requirements.txt (line 6)) (1.35.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.5->-r ./requirements.txt (line 6)) (1.8.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.5->-r ./requirements.txt (line 6)) (57.4.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.5->-r ./requirements.txt (line 6)) (1.0.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.5->-r ./requirements.txt (line 6)) (1.42.0)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.5->-r ./requirements.txt (line 6)) (3.17.3)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.5->-r ./requirements.txt (line 6)) (3.3.6)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.5->-r ./requirements.txt (line 6)) (0.4.6)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from absl-py>=0.4->tensorboard>=2.2.0->pytorch-lightning>=1.5->-r ./requirements.txt (line 6)) (1.15.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.5->-r ./requirements.txt (line 6)) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.5->-r ./requirements.txt (line 6)) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.5->-r ./requirements.txt (line 6)) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.5->-r ./requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.5->-r ./requirements.txt (line 6)) (4.8.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.5->-r ./requirements.txt (line 6)) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.5->-r ./requirements.txt (line 6)) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.5->-r ./requirements.txt (line 6)) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.5->-r ./requirements.txt (line 6)) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.5->-r ./requirements.txt (line 6)) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.5->-r ./requirements.txt (line 6)) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.5->-r ./requirements.txt (line 6)) (3.1.1)
# Collecting antlr4-python3-runtime==4.8
#   Downloading antlr4-python3-runtime-4.8.tar.gz (112 kB)
#      |████████████████████████████████| 112 kB 90.8 MB/s
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->-r ./requirements.txt (line 10)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->-r ./requirements.txt (line 10)) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->-r ./requirements.txt (line 10)) (2.8.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.5->-r ./requirements.txt (line 6)) (21.2.0)
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.2.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (192 kB)
#      |████████████████████████████████| 192 kB 70.5 MB/s
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 86.4 MB/s
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.5->-r ./requirements.txt (line 6)) (2.0.8)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-5.2.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (160 kB)
#      |████████████████████████████████| 160 kB 81.0 MB/s
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.1-py3-none-any.whl (5.7 kB)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from ftfy->clip==1.0->-r ./requirements.txt (line 9)) (0.2.5)
# Building wheels for collected packages: clip, future, antlr4-python3-runtime, ftfy
#   Building wheel for clip (setup.py) ... done
#   Created wheel for clip: filename=clip-1.0-py3-none-any.whl size=1369106 sha256=a8f311e9e8bd7055492ffa453708cc1306d46e4f0034198eae53be9a341a89eb
#   Stored in directory: /tmp/pip-ephem-wheel-cache-0gpqgdm8/wheels/fd/b9/c3/5b4470e35ed76e174bff77c92f91da82098d5e35fd5bc8cdac
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491070 sha256=6dbea3d514bad3008b015538a329bde912e3e61d07909feb987e450dca575e50
#   Stored in directory: /root/.cache/pip/wheels/56/b0/fe/4410d17b32f1f0c3cf54cdfb2bc04d7b4b8f4ae377e2229ba0
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.8-py3-none-any.whl size=141230 sha256=6ae9f4a3f6230ee625953cca7bb7388092e9e1cf66630c87e9ecc8f61cfa7e6e
#   Stored in directory: /root/.cache/pip/wheels/ca/33/b7/336836125fc9bb4ceaa4376d8abca10ca8bc84ddc824baea6c
#   Building wheel for ftfy (setup.py) ... done
#   Created wheel for ftfy: filename=ftfy-6.0.3-py3-none-any.whl size=41933 sha256=b711bfc3d43cac258037e905b966bec685eab6b1f00714988506c93ed69c2b98
#   Stored in directory: /root/.cache/pip/wheels/19/f5/38/273eb3b5e76dfd850619312f693716ac4518b498f5ffb6f56d
# Successfully built clip future antlr4-python3-runtime ftfy
# Installing collected packages: multidict, frozenlist, yarl, asynctest, async-timeout, aiosignal, torch, fsspec, aiohttp, torchvision, torchmetrics, PyYAML, pyDeprecate, future, ftfy, antlr4-python3-runtime, tokenizers, pytorch-lightning, pyflakes, omegaconf, einops, clip
#   Attempting uninstall: torch
#     Found existing installation: torch 1.10.0+cu111
#     Uninstalling torch-1.10.0+cu111:
#       Successfully uninstalled torch-1.10.0+cu111
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.11.1+cu111
#     Uninstalling torchvision-0.11.1+cu111:
#       Successfully uninstalled torchvision-0.11.1+cu111
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: future
#     Found existing installation: future 0.16.0
#     Uninstalling future-0.16.0:
#       Successfully uninstalled future-0.16.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.11.0 requires torch==1.10.0, but you have torch 1.8.0 which is incompatible.
# torchaudio 0.10.0+cu111 requires torch==1.10.0, but you have torch 1.8.0 which is incompatible.
# Successfully installed PyYAML-6.0 aiohttp-3.8.1 aiosignal-1.2.0 antlr4-python3-runtime-4.8 async-timeout-4.0.1 asynctest-0.13.0 clip-1.0 einops-0.3.2 frozenlist-1.2.0 fsspec-2021.11.1 ftfy-6.0.3 future-0.18.2 multidict-5.2.0 omegaconf-2.1.1 pyDeprecate-0.3.1 pyflakes-2.4.0 pytorch-lightning-1.5.6 tokenizers-0.10.3 torch-1.8.0 torchmetrics-0.6.2 torchvision-0.9.0 yarl-1.7.2

# %% [markdown]
# On the first run, restart the Runtime and run the previous cell again

# %%
# !pip install torchtext==0.9
# Out:
# Collecting torchtext==0.9
#   Downloading torchtext-0.9.0-cp37-cp37m-manylinux1_x86_64.whl (7.1 MB)
#      |████████████████████████████████| 7.1 MB 4.6 MB/s
# Requirement already satisfied: torch==1.8.0 in /usr/local/lib/python3.7/dist-packages (from torchtext==0.9) (1.8.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchtext==0.9) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from torchtext==0.9) (4.62.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchtext==0.9) (1.19.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.8.0->torchtext==0.9) (3.10.0.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.9) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.9) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.9) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.9) (2021.10.8)
# Installing collected packages: torchtext
#   Attempting uninstall: torchtext
#     Found existing installation: torchtext 0.11.0
#     Uninstalling torchtext-0.11.0:
#       Successfully uninstalled torchtext-0.11.0
# Successfully installed torchtext-0.9.0

# %%
import os
import sys
import math
import argparse
import clip
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from PIL import Image

sys.path.append(os.path.dirname(os.getcwd()))

from dalle.models import Dalle
from dalle.utils.utils import set_seed, clip_score

device = 'cuda:0'
model = Dalle.from_pretrained("minDALL-E/1.3B")
model_clip, preprocess_clip = clip.load("ViT-B/32", device=device)

model_clip.to(device=device)
model.to(device=device)

def sampling(prompt, top_k, softmax_temperature, seed, num_candidates=8, num_samples_for_display=4):
    # Setup
    n_row = int(math.sqrt(num_samples_for_display))
    n_col = int(math.sqrt(num_samples_for_display))
    set_seed(seed)
    
    # Sampling
    images = model.sampling(prompt=prompt,
                            top_k=top_k,
                            top_p=None,
                            softmax_temperature=softmax_temperature,
                            num_candidates=num_candidates,
                            device=device).cpu().numpy()
    images = np.transpose(images, (0, 2, 3, 1))

    # CLIP Re-ranking
    rank = clip_score(prompt=prompt, images=images, model_clip=model_clip, preprocess_clip=preprocess_clip, device=device)
    images = images[rank]
    
    images = images[:num_samples_for_display]
    fig = plt.figure(figsize=(8*n_row, 8*n_col))

    for i in range(num_samples_for_display):
        ax = fig.add_subplot(n_row, n_col, i+1)
        ax.imshow(images[i])
        ax.set_axis_off()

    plt.tight_layout()
    plt.show()
# Out:
# 100%|█████████████████████████████████████| 4.72G/4.72G [05:11<00:00, 16.3MiB/s]
# extracting: ./1.3B/tokenizer/bpe-16k-vocab.json (size:0MB): 100%|██████████| 7/7 [00:46<00:00,  6.67s/it]
# /root/.cache/minDALL-E/1.3B/tokenizer successfully restored..
# /root/.cache/minDALL-E/1.3B/stage1_last.ckpt successfully restored..
# /root/.cache/minDALL-E/1.3B/stage2_last.ckpt succesfully restored..
# 100%|███████████████████████████████████████| 338M/338M [00:05<00:00, 59.9MiB/s]

# %%
import ipywidgets as widgets
from IPython.display import display
from IPython.display import clear_output

output = widgets.Output()
plot_output = widgets.Output()

def btn_eventhandler(obj):
    output.clear_output()
    plot_output.clear_output()
    
    with output:
        print(f'SEED: {slider_seed.value}')
        print(f'Softmax Temperature: {slider_temp.value}')
        print(f'Top-K: {slider_topk.value}')
        print(f'Text prompt: {wd_text.value}')
        
    with plot_output:
        sampling(prompt=wd_text.value, top_k=slider_topk.value, softmax_temperature=slider_temp.value, seed=slider_seed.value)
    
slider_seed = widgets.IntSlider(
    min=0,
    max=1024,
    step=1,
    description='RND SEED: ',
    value=0
)
slider_topk = widgets.IntSlider(
    min=0,
    max=512,
    step=16,
    description='TOP-K:',
    value=256
)
slider_temp = widgets.FloatSlider(
    min=0.0,
    max=5.0,
    step=0.2,
    description='SOFTMAX TEMPERATURE:',
    value=1.0
)
wd_text = widgets.Text(
    value='A painting of a monkey with sunglasses in the frame',
    placeholder='Text prompt',
    description='String:',
    disabled=False
)

display(slider_seed)
display(slider_temp)
display(slider_topk)
display(wd_text)

btn = widgets.Button(description='Generate!')
display(btn)
btn.on_click(btn_eventhandler)

display(output)
display(plot_output)
# Out:
# IntSlider(value=0, description='RND SEED: ', max=1024)
# FloatSlider(value=1.0, description='SOFTMAX TEMPERATURE:', max=5.0, step=0.2)
# IntSlider(value=256, description='TOP-K:', max=512, step=16)
# Text(value='A painting of a monkey with sunglasses in the frame', description='String:', placeholder='Text pro…
# Button(description='Generate!', style=ButtonStyle())
# Output()
# Output()
