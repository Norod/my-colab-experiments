# %% [markdown]
# <a href="https://colab.research.google.com/github/Norod/my-colab-experiments/blob/master/Simple_U_2_Net_Example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/
# !git clone https://github.com/NathanUA/U-2-Net
# %cd /content/U-2-Net
# %mkdir saved_models
# %mkdir saved_models/u2net
# !wget 'https://norod78.s3-eu-west-1.amazonaws.com/models/u2net/u2net.pth' -O /content/U-2-Net/saved_models/u2net/u2net.pth
# Out:
# /content
# Cloning into 'U-2-Net'...
# remote: Enumerating objects: 401, done.
# remote: Total 401 (delta 0), reused 0 (delta 0), pack-reused 401
# Receiving objects: 100% (401/401), 20.30 MiB | 14.19 MiB/s, done.
# Resolving deltas: 100% (154/154), done.
# /content/U-2-Net
# mkdir: cannot create directory ‘saved_models’: File exists
# --2020-11-26 16:01:03--  https://norod78.s3-eu-west-1.amazonaws.com/models/u2net/u2net.pth
# Resolving norod78.s3-eu-west-1.amazonaws.com (norod78.s3-eu-west-1.amazonaws.com)... 52.218.29.160
# Connecting to norod78.s3-eu-west-1.amazonaws.com (norod78.s3-eu-west-1.amazonaws.com)|52.218.29.160|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 176290937 (168M) [application/x-www-form-urlencoded]
# Saving to: ‘/content/U-2-Net/saved_models/u2net/u2net.pth’
#
# /content/U-2-Net/sa 100%[===================>] 168.12M   101MB/s    in 1.7s
#
# ...

# %% [markdown]
# This command just empties the results folders of their default images

# %%
# !rm /content/U-2-Net/test_data/u2net_results/*
# !rm /content/U-2-Net/test_data/test_images/*
# !rm -rf /content/U-2-Net/test_data/u2netp_results

# %%
#Use muppet sample images or download / upload your own
# !wget https://storage.googleapis.com/misc-image-dataset/few-muppets.zip
# !unzip -nj /content/U-2-Net/few-muppets.zip -d ./test_data/test_images/

# %% [markdown]
# Add your own images to the `U-2-Net/test_data/test_images/` folder. Then run the following command.

# %%
# !python u2net_test.py
# Out:
# ['/content/U-2-Net/test_data/test_images/Ernie_2_070182985_229.jpg', '/content/U-2-Net/test_data/test_images/Fozzie_1_033502227_2648.jpg', '/content/U-2-Net/test_data/test_images/Ernie_2_080089235_144.jpg', '/content/U-2-Net/test_data/test_images/Animal_1_074360114_1281.jpg', '/content/U-2-Net/test_data/test_images/Fozzie_2_05423014_1422.jpg', '/content/U-2-Net/test_data/test_images/Ernie_1_088057244_952.jpg', '/content/U-2-Net/test_data/test_images/Bert_1_082240045_143.jpg', '/content/U-2-Net/test_data/test_images/Animal_1_049592763_1864.jpg', '/content/U-2-Net/test_data/test_images/Elmo_1_099233127_524.jpg', '/content/U-2-Net/test_data/test_images/Gonzo_3_085598284_2266.jpg', '/content/U-2-Net/test_data/test_images/Gonzo_4_09298218_1370.jpg', '/content/U-2-Net/test_data/test_images/Grover_4_090627193_1935.jpg', '/content/U-2-Net/test_data/test_images/Piggy_1_02725706_2578.jpg', '/content/U-2-Net/test_data/test_images/BigBird_1_09184797_320.jpg', '/content/U-2-Net/test_data/test_ima
# ...

# %%
# !zip few-muppets-Masked.zip ./test_data/u2net_results/*
# Out:
#   adding: test_data/u2net_results/Animal_1_04554255_187.png (deflated 4%)
#   adding: test_data/u2net_results/Animal_1_046816397_1655.png (deflated 0%)
#   adding: test_data/u2net_results/Animal_1_049592763_1864.png (deflated 3%)
#   adding: test_data/u2net_results/Animal_1_057793874_917.png (deflated 1%)
#   adding: test_data/u2net_results/Animal_1_06126689_2639.png (deflated 1%)
#   adding: test_data/u2net_results/Animal_1_074360114_1281.png (deflated 4%)
#   adding: test_data/u2net_results/Animal_1_07523914_1738.png (deflated 3%)
#   adding: test_data/u2net_results/Animal_1_075849724_181.png (deflated 1%)
#   adding: test_data/u2net_results/Animal_1_080236876_152.png (deflated 2%)
#   adding: test_data/u2net_results/Animal_1_080977875_53.png (deflated 1%)
#   adding: test_data/u2net_results/Animal_1_081702536_2278.png (deflated 2%)
#   adding: test_data/u2net_results/Animal_1_082313067_2272.png (deflated 3%)
# ...

# %%
#Now download the result:
# !ls -latr /content/U-2-Net/few-muppets.zip
# Out:
# -rw-r--r-- 1 root root 17510965 Aug 18 14:37 /content/U-2-Net/few-muppets.zip
